# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm

# Load data
data = pd.read_csv(r"CLEAN_DATA/Europe_2015_manifesto_gini_ps.csv")
welfare = pd.read_csv(r"RAW_DATA/social_welfare_spending.csv")
welfare = welfare[['Reference area', 'TIME_PERIOD', 'OBS_VALUE']]
welfare.rename(columns={'Reference area': 'countryname', 'TIME_PERIOD': 'year', 'OBS_VALUE': 'welfare spending'}, inplace=True)


display(data.head(20))
display(welfare.head(20))
# Out:
# /var/folders/bb/hkfpdvbn46vcqvd2x75jvk0h0000gn/T/ipykernel_9780/3286726041.py:7: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(r"CLEAN_DATA/Europe_2015_manifesto_gini_ps.csv")
#     Unnamed: 0.1  Unnamed: 0  country countryname  oecdmember  eumember  \
# 0              0           0       11      Sweden           0       0.0
# 1              1           1       11      Sweden           0       0.0
# 2              2           2       11      Sweden           0       0.0
# 3              3           3       11      Sweden           0       0.0
# 4              4           4       11      Sweden           0       0.0
# 5              5           5       11      Sweden           0       0.0
# 6              6           6       11      Sweden           0       0.0
# 7              7           7       11      Sweden           0       0.0
# 8              8           8       11      Sweden           0       0.0
# 9              9           9       11      Sweden           0       0.0
# 10            10          10       11      Sweden           0       0.0
# 11            11          11       11      Sweden           0       0.0
# 12            12          12       11      Sweden           0       0.0
# 13            13          13       11      Sweden           0       0.0
# 14            14          14       11      Sweden           0       0.0
# 15            15          15       11      Sweden           0       0.0
# 16            16          16       11      Sweden           0       0.0
# 17            17          17       11      Sweden           0       0.0
# 18            18          18       11      Sweden           0       0.0
# 19            19          19       11      Sweden           0       0.0
#
#          edate    date  party                       partyname  ... per703_2  \
# 0   1944-09-17  194409  11220       Communist Party of Sweden  ...      NaN
# 1   1944-09-17  194409  11320  Social Democratic Labour Party  ...      NaN
# 2   1944-09-17  194409  11420                  People’s Party  ...      NaN
# 3   1944-09-17  194409  11620                     Right Party  ...      NaN
# 4   1944-09-17  194409  11810                  Agrarian Party  ...      NaN
# 5   1948-09-19  194809  11220       Communist Party of Sweden  ...      NaN
# 6   1948-09-19  194809  11320  Social Democratic Labour Party  ...      NaN
# 7   1948-09-19  194809  11420                  People’s Party  ...      NaN
# 8   1948-09-19  194809  11620                     Right Party  ...      NaN
# 9   1948-09-19  194809  11810                  Agrarian Party  ...      NaN
# 10  1952-09-21  195209  11220       Communist Party of Sweden  ...      NaN
# 11  1952-09-21  195209  11320  Social Democratic Labour Party  ...      NaN
# 12  1952-09-21  195209  11420                  People’s Party  ...      NaN
# 13  1952-09-21  195209  11620                     Right Party  ...      NaN
# 14  1952-09-21  195209  11810                  Agrarian Party  ...      NaN
# 15  1956-09-26  195609  11220       Communist Party of Sweden  ...      NaN
# 16  1956-09-26  195609  11320  Social Democratic Labour Party  ...      NaN
# 17  1956-09-26  195609  11420                  People’s Party  ...      NaN
# 18  1956-09-26  195609  11620                     Right Party  ...      NaN
# 19  1956-09-26  195609  11810                  Agrarian Party  ...      NaN
#
#      rile planeco  markeco  welfare  intpeace  datasetversion  id_perm  \
# 0    9.60     1.9    1.900      0.0     1.900           2023a   JN1LZH
# 1  -37.80     3.3    2.200     33.4     5.600           2023a   CMR7F6
# 2    9.50     3.2    6.400     14.3     1.600           2023a   Z6OL6C
# 3   28.00     1.8   22.800     10.6     0.000           2023a   YMKVN2
# 4   23.81     0.0   19.048      0.0     4.762           2023a   U4SCRD
# 5  -44.00     8.0    2.000     18.0    10.000           2023a   KU4SLH
# 6  -33.40     6.7    5.800     20.8     1.700           2023a   SUX4JY
# 7   22.90     2.3   13.700      7.0     4.600           2023a   RGU9EV
# 8   56.30     0.0   50.000      0.0     3.100           2023a   FU1SGP
# 9   -4.90     3.5    9.200     13.5     0.700           2023a   H326HA
# 10 -40.70     3.3    3.300      8.8    40.700           2023a   8Y82JK
# 11 -28.30     1.6    4.200     20.8     2.500           2023a   AGKM5T
# 12  16.10     0.9   16.100     21.7     0.900           2023a   3ENRXJ
# 13  40.90     0.0   31.900      0.8     0.000           2023a   3ERZTJ
# 14   1.20     0.0   13.500     13.6     2.700           2023a   PZO59H
# 15 -46.20    10.1    0.800     23.5    13.400           2023a   8S4LJX
# 16 -44.20     8.1    3.500     27.3     2.900           2023a   87HOAY
# 17 -17.30     2.8    6.800     21.9     2.800           2023a   CSX8VJ
# 18  53.70     0.0   35.900     10.3     0.000           2023a   I4XTSW
# 19   1.80     0.0    6.300      7.2     3.600           2023a   KKH27B
#
#     Gini coefficient  stance_positivity_score
# 0                NaN                    3.800
# 1                NaN                   21.000
# 2                NaN                   39.900
# 3                NaN                   29.900
# 4                NaN                   33.334
# 5                NaN                   10.000
# 6                NaN                   31.600
# 7                NaN                   27.600
# 8                NaN                    9.400
# 9                NaN                   52.700
# 10               NaN                    1.100
# 11               NaN                   31.600
# 12               NaN                   27.000
# 13               NaN                    4.900
# 14               NaN                   47.200
# 15               NaN                   18.400
# 16               NaN                   26.200
# 17               NaN                   19.900
# 18               NaN                   20.500
# 19               NaN                   59.900
#
# [20 rows x 179 columns]
#    countryname  year  welfare spending
# 0       Sweden  2015            26.107
# 1       Sweden  2016            26.527
# 2       Sweden  2017            25.859
# 3       Sweden  2018            25.633
# 4       Sweden  2019            25.072
# 5       Sweden  2020            25.855
# 6    Lithuania  2015            15.805
# 7    Lithuania  2016            15.573
# 8    Lithuania  2017            15.334
# 9    Lithuania  2018            16.398
# 10   Lithuania  2019            16.993
# 11   Lithuania  2020            21.076
# 12     Iceland  2015            16.648
# 13     Iceland  2016            16.491
# 14     Iceland  2017            17.496
# 15     Iceland  2018            17.779
# 16     Iceland  2019            18.691
# 17     Iceland  2020            23.013
# 18  Luxembourg  2015            20.543
# 19  Luxembourg  2016            20.251
