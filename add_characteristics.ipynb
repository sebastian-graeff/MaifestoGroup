# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm

# Load data
data = pd.read_csv(r"CLEAN_DATA/Europe_2015_manifesto_gini_ps.csv")
welfare = pd.read_csv(r"RAW_DATA/social_welfare_spending.csv")

# Reduce dataframe to country, year and welfare spending and rename them
welfare = welfare[['Reference area', 'TIME_PERIOD', 'OBS_VALUE']]
welfare.rename(columns={'Reference area': 'countryname', 'TIME_PERIOD': 'year', 'OBS_VALUE': 'welfare spending'}, inplace=True)
# Out:
# /var/folders/bb/hkfpdvbn46vcqvd2x75jvk0h0000gn/T/ipykernel_9780/1168233434.py:7: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(r"CLEAN_DATA/Europe_2015_manifesto_gini_ps.csv")

# %%
# extract the year from the edate column
data['year'] = pd.to_datetime(data['edate']).dt.year
# merge the two datasets
merged_df = pd.merge(data, welfare, on=['countryname', 'year'], how='left')
#reduce it to only 2015-2020
merged_df = merged_df[(merged_df['year'] >= 2015) & (merged_df['year'] <= 2020)]

display(merged_df.head())
# Out:
#      Unnamed: 0.1  Unnamed: 0  country countryname  oecdmember  eumember  \
# 129           129         129       11      Sweden          10      10.0
# 130           130         130       11      Sweden          10      10.0
# 131           131         131       11      Sweden          10      10.0
# 132           132         132       11      Sweden          10      10.0
# 133           133         133       11      Sweden          10      10.0
#
#           edate    date  party                       partyname  ... planeco  \
# 129  2018-09-09  201809  11110             Green Ecology Party  ...   0.000
# 130  2018-09-09  201809  11220                      Left Party  ...   1.067
# 131  2018-09-09  201809  11320  Social Democratic Labour Party  ...   0.645
# 132  2018-09-09  201809  11420                        Liberals  ...   1.144
# 133  2018-09-09  201809  11520             Christian Democrats  ...   2.542
#
# ...
