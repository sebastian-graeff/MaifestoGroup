# %%
import pandas as pd

# load data
df = pd.read_csv(r"CLEAN_DATA/Europe_2015_2020_manifesto_gini_ps.csv")
df
# Out:
#      Unnamed: 0.1  Unnamed: 0  country countryname  oecdmember  eumember  \
# 0               0         129       11      Sweden          10      10.0
# 1               1         130       11      Sweden          10      10.0
# 2               2         131       11      Sweden          10      10.0
# 3               3         132       11      Sweden          10      10.0
# 4               4         133       11      Sweden          10      10.0
# ..            ...         ...      ...         ...         ...       ...
# 449           449        4665       98     Ukraine           0       0.0
# 450           450        4666       98     Ukraine           0       0.0
# 451           451        4667       98     Ukraine           0       0.0
# 452           452        4668       98     Ukraine           0       0.0
# 453           453        4669       98     Ukraine           0       0.0
#
#           edate    date  party                         partyname  ...  \
# 0    2018-09-09  201809  11110               Green Ecology Party  ...
# 1    2018-09-09  201809  11220                        Left Party  ...
# 2    2018-09-09  201809  11320    Social Democratic Labour Party  ...
# 3    2018-09-09  201809  11420                          Liberals  ...
# 4    2018-09-09  201809  11520               Christian Democrats  ...
# ..          ...     ...    ...                               ...  ...
# 449  2019-07-21  201907  98350                   Opposition Bloc  ...
# 450  2019-07-21  201907  98440             Servant of the People  ...
# 451  2019-07-21  201907  98450                             Voice  ...
# 452  2019-07-21  201907  98617  All-Ukrainian Union ‘Fatherland'  ...
# 453  2019-07-21  201907  98631               European Solidarity  ...
#
#     per703_2    rile  planeco  markeco  welfare  intpeace  datasetversion  \
# 0        0.0 -15.966    0.000    0.168   18.487     2.353           2023a
# 1        0.0 -40.701    1.067    0.000   37.652     3.506           2023a
# 2        0.0 -20.000    0.645    0.000   22.258     0.645           2023a
# 3        0.0  -1.144    1.144    2.778   16.503     0.000           2023a
# 4        0.0 -12.712    2.542    0.000   34.746     0.000           2023a
# ..       ...     ...      ...      ...      ...       ...             ...
# 449      0.0  -4.717    1.887    1.887   13.208    12.264           2023a
# 450      0.0   2.128    8.511    3.191    4.255     0.000           2023a
# 451      0.0  22.892    3.614    2.410    3.614     9.639           2023a
# 452      0.0 -23.377    5.195    3.896   15.584     5.195           2023a
# 453      0.0  25.000    3.409    1.136    4.545     5.682           2023a
#
#      id_perm  Gini coefficient  stance_positivity_score
# 0     VXLO39          0.299742                   63.025
# 1     IJRAPK          0.299742                   53.201
# 2     GV4CQK          0.299742                   68.064
# 3     7O4BQ2          0.299742                   50.814
# 4     4FL7IT          0.299742                   55.086
# ..       ...               ...                      ...
# 449   ZHUFI7          0.266195                   62.262
# 450   RB6257          0.266195                   62.767
# 451   JT5WL6          0.266195                   48.192
# 452   W96R9B          0.266195                   70.129
# 453   JC6ADL          0.266195                   77.272
#
# [454 rows x 179 columns]

# %%
# Filter the DataFrame
df = df[['date', 'countryname', 'rile', 'stance_positivity_score', 'Gini coefficient', 'absseat']]

# Convert 'date' to datetime and extract the year for grouping
df['year'] = pd.to_datetime(filtered_df['date']).dt.year

# Calculate mean values for each group
mean_values = df.groupby(['countryname', 'year']).transform('mean')

# Since transform keeps the original index, copy the mean values directly into the original df
df['mean_rile'] = mean_values['rile']
df['mean_stance_positivity_score'] = mean_values['stance_positivity_score']
df['mean_gini_coefficient'] = mean_values['Gini coefficient']

# Now, calculate 'leading' for each group
# First, mark each row as 'left' or 'right' based on 'rile'
df['side'] = df['rile'].apply(lambda x: 'left' if x < 0 else 'right')

# Initialize an empty column for 'leading'
df['leading'] = None

# Iterate through each group to determine the leading side
for (countryname, year), group in df.groupby(['countryname', 'year']):
    left_sum = group[group['side'] == 'left']['absseat'].sum()
    right_sum = group[group['side'] == 'right']['absseat'].sum()
    leading_side = 'left' if left_sum > right_sum else 'right'
    
    # Assign the 'leading' side to the original df
    df.loc[(df['countryname'] == countryname) & (df['year'] == year), 'leading'] = leading_side

# Drop duplicates since each country-year group now has the same 'leading' value and mean calculations
final_df = df[['countryname', 'year', 'mean_rile', 'mean_stance_positivity_score', 'mean_gini_coefficient', 'leading']].drop_duplicates()

# Optionally, rename the columns back
final_df.columns = ['countryname', 'year', 'rile', 'leading', 'stance_positivity_score', 'gini Coefficient']

# Display the final DataFrame
display(final_df.head())
# Out:
# /var/folders/bb/hkfpdvbn46vcqvd2x75jvk0h0000gn/T/ipykernel_44884/480645805.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = pd.to_datetime(filtered_df['date']).dt.year
# /var/folders/bb/hkfpdvbn46vcqvd2x75jvk0h0000gn/T/ipykernel_44884/480645805.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mean_rile'] = mean_values['rile']
# /var/folders/bb/hkfpdvbn46vcqvd2x75jvk0h0000gn/T/ipykernel_44884/480645805.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mean_stance_positivity_score'] = mean_values['stance_positivity_score']
# /var/folders/bb/hkfpdvbn46vcqvd2x75jvk0h0000gn/T/ipykernel_44884/480645805.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mean_gini_coefficient'] = mean_values['Gini coefficient']
# /var/folders/bb/hkfpdvbn46vcqvd2x75jvk0h0000gn/T/ipykernel_44884/480645805.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['side'] = df['rile'].apply(lambda x: 'left' if x < 0 else 'right')
# /var/folders/bb/hkfpdvbn46vcqvd2x75jvk0h0000gn/T/ipykernel_44884/480645805.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['leading'] = None
#    countryname  year       rile    leading  stance_positivity_score  \
# 0       Sweden  1970 -10.283625  58.764000                 0.299742
# 8       Norway  1970 -15.352667  60.142444                 0.269873
# 17     Denmark  1970  -6.543842  50.180000                 0.279386
# 36     Finland  1970 -19.870412  50.911235                 0.274384
# 53     Iceland  1970 -20.732533  45.709688                 0.266170
#
#    gini Coefficient
# 0              left
# 8              left
# 17             left
# 36             left
# 53             left

# %%
#save as csv 
final_df.to_csv("CLEAN_DATA/2015-2020_percountry_peryear.csv")
