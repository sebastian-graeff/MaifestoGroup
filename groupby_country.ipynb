# %% [markdown]
# This Notebook is

# %%
import pandas as pd

# load data
df = pd.read_csv(r"CLEAN_DATA/Europe_2015_2020_manifesto_gini_ps.csv")

display(df.head(20))
df['Success'] = data['absseat'].apply(lambda x: 1 if x > 0 else 0)
# Out:
#     Unnamed: 0.1  Unnamed: 0  country countryname  oecdmember  eumember  \
# 0              0         129       11      Sweden          10      10.0
# 1              1         130       11      Sweden          10      10.0
# 2              2         131       11      Sweden          10      10.0
# 3              3         132       11      Sweden          10      10.0
# 4              4         133       11      Sweden          10      10.0
# 5              5         134       11      Sweden          10      10.0
# 6              6         135       11      Sweden          10      10.0
# 7              7         136       11      Sweden          10      10.0
# 8              8         258       12      Norway          10       0.0
# 9              9         259       12      Norway          10       0.0
# 10            10         260       12      Norway          10       0.0
# 11            11         261       12      Norway          10       0.0
# ...

# %%
# Step 1: Filter the DataFrame
filtered_df = df[['date', 'countryname', 'rile','Success', 'stance_positivity_score', 'Gini coefficient']]

# Convert 'date' to datetime and extract the year for grouping
filtered_df['year'] = pd.to_datetime(filtered_df['date']).dt.year

# Step 2: Split the data into two groups based on the 'rile' sign and calculate the mean for required columns
def group_and_calculate_means(sub_df):
    # Group by 'rile' sign (positive or negative)
    sub_df['rile_sign'] = sub_df['rile'].apply(lambda x: 'positive' if x > 0 else 'negative')
    
    # Calculate mean for 'rile', 'stance_positivity_score', and 'gini Coefficient'
    return sub_df.groupby(['countryname', 'year', 'rile_sign'])[['rile', 'stance_positivity_score', 'Gini coefficient']].mean().reset_index()

# Apply the function
grouped_means_df = group_and_calculate_means(filtered_df)

# Since the output is already grouped and calculated, this is your final DataFrame
final_df = grouped_means_df

# Display the final DataFrame (optional)
display(final_df)
# Out:
# /var/folders/bb/hkfpdvbn46vcqvd2x75jvk0h0000gn/T/ipykernel_36228/2079873600.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['year'] = pd.to_datetime(filtered_df['date']).dt.year
# /var/folders/bb/hkfpdvbn46vcqvd2x75jvk0h0000gn/T/ipykernel_36228/2079873600.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['rile_sign'] = sub_df['rile'].apply(lambda x: 'positive' if x > 0 else 'negative')
#        countryname  year rile_sign       rile  stance_positivity_score  \
# ...

# %%
#save as csv 
df.to_csv("CLEAN_DATA/2015-2020_percountry_peryear.csv")
