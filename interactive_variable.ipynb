# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset 
df = pd.read_csv('CLEAN_DATA/2005-2020_percountry_peryear.csv')

# %%
display(df)
# Out:
#     Unnamed: 0     countryname  year       rile    leading  \
# 0            0          Sweden  1970  -9.664581  45.902032
# 1           31          Norway  1970 -15.827323  51.918645
# 2           62         Denmark  1970  -6.841977  36.096295
# 3          106         Finland  1970 -19.596515  47.554121
# 4          139         Iceland  1970 -14.290000  43.273094
# 5          171         Belgium  1970  -4.707953  47.491977
# 6          214     Netherlands  1970   3.591386  41.734091
# 7          258      Luxembourg  1970 -17.430917  34.965833
# 8          270          France  1970 -15.365846  51.078385
# 9          296           Italy  1970   2.513000  41.909891
# 10         342           Spain  1970 -18.258911  47.166975
# 11         421          Greece  1970  -3.099182  38.257224
# 12         470        Portugal  1970 -10.660114  45.163114
# 13         505         Germany  1970  -8.037739  41.027652
# 14         528         Austria  1970  -9.320786  49.650857
# 15         556     Switzerland  1970  -2.923000  37.756705
# 16         600  United Kingdom  1970 -10.223194  44.888750
# 17         636         Ireland  1970 -17.216609  34.745043
# 18         659          Cyprus  1970   0.211750  49.972100
# 19         679        Bulgaria  1970   0.062433  48.758968
# 20         710         Croatia  1970  -9.433079  57.873436
# 21         749  Czech Republic  1970 -12.334276  40.848655
# 22         778         Estonia  1970  -2.739261  60.599609
# 23         801         Hungary  1970  -5.683478  52.566304
# 24         824          Latvia  1970   6.750400  73.787867
# 25         854       Lithuania  1970  -6.257300  54.933033
# 26         884         Moldova  1970  -2.976273  48.248909
# 27         906      Montenegro  1970   0.792129  71.307129
# 28         937          Poland  1970  -1.138594  52.096969
# 29         969         Romania  1970  -4.211071  50.811357
# 30         983          Russia  1970  -1.710625  40.569375
# 31         991          Serbia  1970   1.355571  44.801667
# 32        1036        Slovakia  1970   6.621033  48.908000
# 33        1066        Slovenia  1970  -3.491559  52.951765
# 34        1100         Ukraine  1970   1.164621  56.295000
#
#     stance_positivity_score gini Coefficient
# 0                  0.281705             left
# 1                  0.274538             left
# 2                  0.269428             left
# 3                  0.276933             left
# 4                  0.271539             left
# 5                  0.283807             left
# 6                  0.284928            right
# 7                  0.316165             left
# 8                  0.323860             left
# 9                  0.344132             left
# 10                 0.350712             left
# 11                 0.352115             left
# 12                 0.353612             left
# 13                 0.313809            right
# 14                 0.301630             left
# 15                 0.327728            right
# 16                 0.332149             left
# 17                 0.326035             left
# 18                 0.322822             left
# 19                 0.369773             left
# 20                 0.307847             left
# 21                      NaN             left
# 22                 0.318213             left
# 23                 0.297742             left
# 24                 0.353209            right
# 25                 0.365525             left
# 26                 0.302661             left
# 27                 0.338336             left
# 28                 0.325029            right
# 29                 0.284105            right
# 30                 0.410109             left
# 31                 0.361160             left
# 32                 0.264702             left
# 33                 0.246979             left
# 34                 0.262981            right

# %%
df['RILE_stance_score_interaction'] = df['rile'] * df['stance_positivity_score']

# %%
display(df['RILE_stance_score_interaction'])
# Out:
# 0    -2.722556
# 1    -4.345198
# 2    -1.843421
# 3    -5.426925
# 4    -3.880299
# 5    -1.336149
# 6     1.023285
# 7    -5.511043
# 8    -4.976381
# 9     0.864804
# 10   -6.403621
# 11   -1.091269
# 12   -3.769539
# 13   -2.522315
# 14   -2.811430
# 15   -0.957950
# 16   -3.395626
# 17   -5.613209
# 18    0.068357
# 19    0.023086
# 20   -2.903944
# 21         NaN
# 22   -0.871669
# 23   -1.692209
# 24    2.384304
# 25   -2.287203
# 26   -0.900800
# 27    0.268006
# 28   -0.370076
# 29   -1.196385
# 30   -0.701543
# 31    0.489579
# 32    1.752602
# 33   -0.862341
# 34    0.306273
# Name: RILE_stance_score_interaction, dtype: float64

# %%
#save as csv (ps = positivity score)
df.to_csv("CLEAN_DATA/2005-2020_percountry_peryear_final.csv")
