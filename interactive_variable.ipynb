# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset 
df = pd.read_csv('CLEAN_DATA/2015-2020_percountry_peryear.csv')

# %%
display(df)
# Out:
#     Unnamed: 0     countryname  year       rile  stance_positivity_score  \
# 0            0          Sweden  1970 -10.283625                58.764000
# 1            8          Norway  1970 -15.352667                60.142444
# 2           17         Denmark  1970  -6.543842                50.180000
# 3           36         Finland  1970 -19.870412                50.911235
# 4           53         Iceland  1970 -20.732533                45.709688
# 5           69         Belgium  1970 -11.638571                65.639857
# 6           76     Netherlands  1970  -3.587846                55.206385
# 7           89          France  1970  -8.333300                66.895900
# 8           99           Italy  1970  -0.935364                47.289091
# 9          110           Spain  1970 -19.649655                52.000945
# 10         165          Greece  1970  -9.759000                39.511375
# 11         189        Portugal  1970 -11.042125                54.936000
# ...

# %%
df['RILE_stance_score_interaction'] = df['rile'] * df['stance_positivity_score']

# %%
display(df['RILE_stance_score_interaction'])
# Out:
# 0     -604.306940
# 1     -923.346902
# 2     -328.369997
# 3    -1011.627209
# 4     -947.677620
# 5     -763.954166
# 6     -198.072015
# 7     -557.463603
# 8      -44.232496
# 9    -1021.800614
# 10    -385.591509
# 11    -606.610179
# 12    -618.485193
# 13    -526.774435
# 14    -155.064484
# 15    -629.855821
# 16    -918.289149
# 17    -118.422851
# 18     699.804061
# 19    -500.075693
# 20   -1018.196594
# 21      45.146521
# 22    -539.993018
# 23     406.616750
# 24    -874.829730
# 25    -772.991791
# 26    -144.432344
# 27    -341.921331
# 28    -328.327112
# 29      50.345384
# 30     218.244935
# 31    -428.403162
# 32      86.245542
# Name: RILE_stance_score_interaction, dtype: float64

# %%
#save as csv (ps = positivity score)
df.to_csv("CLEAN_DATA/2015-2020_percountry_peryear_final.csv")
