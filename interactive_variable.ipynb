# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset 
df = pd.read_csv('CLEAN_DATA/Europe_2015_manifesto_gini_ps.csv')
# Out:
# C:\Users\sanne\AppData\Local\Temp\ipykernel_27680\3674099479.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('CLEAN_DATA/Europe_2015_manifesto_gini_ps.csv')

# %%
display(df)
# Out:
#       Unnamed: 0.1  Unnamed: 0  country   countryname  oecdmember  eumember  \
# 0                0           0       11        Sweden           0       0.0
# 1                1           1       11        Sweden           0       0.0
# 2                2           2       11        Sweden           0       0.0
# 3                3           3       11        Sweden           0       0.0
# 4                4           4       11        Sweden           0       0.0
# ...            ...         ...      ...           ...         ...       ...
# 5084          5084        5084      181  South Africa           0       0.0
# 5085          5085        5085      181  South Africa           0       0.0
# 5086          5086        5086      181  South Africa           0       0.0
# 5087          5087        5087      181  South Africa           0       0.0
# 5088          5088        5088      181  South Africa           0       0.0
#
#            edate    date   party                           partyname  ...  \
# 0     1944-09-17  194409   11220           Communist Party of Sweden  ...
# 1     1944-09-17  194409   11320      Social Democratic Labour Party  ...
# 2     1944-09-17  194409   11420                      People’s Party  ...
# 3     1944-09-17  194409   11620                         Right Party  ...
# 4     1944-09-17  194409   11810                      Agrarian Party  ...
# ...          ...     ...     ...                                 ...  ...
# 5084  2019-05-08  201905  181510  African Christian Democratic Party  ...
# 5085  2019-05-08  201905  181520     African Transformation Movement  ...
# 5086  2019-05-08  201905  181710                  Freedom Front Plus  ...
# 5087  2019-05-08  201905  181910               Inkatha Freedom Party  ...
# 5088  2019-05-08  201905  181980        African Independent Congress  ...
#
#      per703_2    rile planeco  markeco  welfare  intpeace  datasetversion  \
# 0         NaN   9.600   1.900    1.900    0.000     1.900           2023a
# 1         NaN -37.800   3.300    2.200   33.400     5.600           2023a
# 2         NaN   9.500   3.200    6.400   14.300     1.600           2023a
# 3         NaN  28.000   1.800   22.800   10.600     0.000           2023a
# 4         NaN  23.810   0.000   19.048    0.000     4.762           2023a
# ...       ...     ...     ...      ...      ...       ...             ...
# 5084      0.0  12.500   0.833    7.500   14.167     0.000           2023a
# 5085      0.0  -6.771   3.385    1.042   22.135     1.562           2023a
# 5086      0.0  19.580   0.699   10.664   11.364     0.000           2023a
# 5087      0.0  -6.579   0.658    0.658   28.947     0.000           2023a
# 5088      0.0 -14.839   2.581    0.000   24.516     0.000           2023a
#
#       id_perm  Gini coefficient  stance_positivity_score
# 0      JN1LZH               NaN                    3.800
# 1      CMR7F6               NaN                   21.000
# 2      Z6OL6C               NaN                   39.900
# 3      YMKVN2               NaN                   29.900
# 4      U4SCRD               NaN                   33.334
# ...       ...               ...                      ...
# 5084   HSQT6Y               NaN                   86.667
# 5085   B6QCSE               NaN                   84.634
# 5086   OS725O               NaN                   67.482
# 5087   XKM7J7               NaN                   82.891
# 5088   GC57QF               NaN                   64.514
#
# [5089 rows x 179 columns]

# %%
df['RILE_stance_score_interaction'] = df['rile'] * df['stance_positivity_score']

# %%
display(df['RILE_stance_score_interaction'])
# Out:
# 0         36.480000
# 1       -793.800000
# 2        379.050000
# 3        837.200000
# 4        793.682540
#            ...
# 5084    1083.337500
# 5085    -573.056814
# 5086    1321.297560
# 5087    -545.339889
# 5088    -957.323246
# Name: RILE_stance_score_interaction, Length: 5089, dtype: float64

# %%
#save as csv (ps = positivity score)
# df.to_csv("CLEAN_DATA/Europe_2015_manifesto_gini_ps.csv")
