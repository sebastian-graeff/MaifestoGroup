# %%
import pandas as pd
import numpy as np
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# Load the dataset 
df = pd.read_csv('CLEAN_DATA/Data_europe_2005_2020.csv')

# %%
#create lists of all positive and negative variables
positive_variables = ['per101','per104','per107','per108','per203','per402','per406','per410','per411','per416','per502','per503','per601','per603','per605','per606','per607','per701','per703','per1011','per1012','per1013','per1014','per1015','per1016','per1032','per1033','per2022','per2023','per2031','per2032','per2033','per2041','per3011','per3052','per3054','per3055','per4011','per4013','per4014','per4121','per4122','per4123','per4124','per5021','per5031','per5041','per5061','per6011','per6012','per6013','per6071','per6072','per7051','per7052','per7061','per7062','per202_1','per202_3','per202_4','per305_4','per416_1','per416_2','per601_1','per602_2','per605_1','per606_1','per607_1','per607_3','per703_1']
negative_variables = ['per102','per105','per109','per110','per204','per407','per602','per604','per608','per702','per1021','per1022','per1023','per1024','per1025','per1026','per1031','per3051','per3053','per4012','per4131','per4132','per6081','per202_2','per305_5','per601_2','per602_1','per605_2','per608_1','per608_3','per703_2']

# %%
# Create a new column 'positivity score' with initial value 0
df['stance_positivity_score'] = 0

# Add up values from titles in List A
df['stance_positivity_score'] += df[positive_variables].sum(axis=1)

# Subtract values from titles in List B
df['stance_positivity_score'] -= df[negative_variables].sum(axis=1)

# %%
display(df)
# Out:
#       country countryname  oecdmember  eumember       edate    date  party  \
# 0          11      Sweden          10      10.0  2006-09-17  200609  11110
# 1          11      Sweden          10      10.0  2006-09-17  200609  11220
# 2          11      Sweden          10      10.0  2006-09-17  200609  11320
# 3          11      Sweden          10      10.0  2006-09-17  200609  11420
# 4          11      Sweden          10      10.0  2006-09-17  200609  11520
# ...       ...         ...         ...       ...         ...     ...    ...
# 1124       98     Ukraine           0       0.0  2019-07-21  201907  98350
# 1125       98     Ukraine           0       0.0  2019-07-21  201907  98440
# 1126       98     Ukraine           0       0.0  2019-07-21  201907  98450
# 1127       98     Ukraine           0       0.0  2019-07-21  201907  98617
# 1128       98     Ukraine           0       0.0  2019-07-21  201907  98631
#
#                              partyname partyabbrev  parfam  ...  welfare  \
# 0                  Green Ecology Party          MP      10  ...   29.798
# 1                           Left Party           V      20  ...   24.679
# 2       Social Democratic Labour Party         SAP      30  ...   29.517
# 3               Liberal People’s Party          FP      40  ...   16.694
# 4                  Christian Democrats          Kd      50  ...   20.968
# ...                                ...         ...     ...  ...      ...
# 1124                   Opposition Bloc         NaN      30  ...   13.208
# 1125             Servant of the People         NaN      40  ...    4.255
# 1126                             Voice         NaN      40  ...    3.614
# 1127  All-Ukrainian Union ‘Fatherland'         NaN      60  ...   15.584
# 1128               European Solidarity         NaN      60  ...    4.545
#
#       intpeace  datasetversion  id_perm  year  Gini coefficient  \
# 0        1.515           2023a   4REHJD  2006          0.263525
# 1        1.028           2023a   PNMPGP  2006          0.263525
# 2        1.781           2023a   K3SXQ7  2006          0.263525
# 3        0.000           2023a   VSD37H  2006          0.263525
# 4        0.000           2023a   H41DX2  2006          0.263525
# ...        ...             ...      ...   ...               ...
# 1124    12.264           2023a   ZHUFI7  2019          0.266195
# 1125     0.000           2023a   RB6257  2019          0.266195
# 1126     9.639           2023a   JT5WL6  2019          0.266195
# 1127     5.195           2023a   W96R9B  2019          0.266195
# 1128     5.682           2023a   JC6ADL  2019          0.266195
#
#       welfare spending  electoral_dem_ind           GNI  \
# 0               26.408              0.915  4.340743e+11
# 1               26.408              0.915  4.340743e+11
# 2               26.408              0.915  4.340743e+11
# 3               26.408              0.915  4.340743e+11
# 4               26.408              0.915  4.340743e+11
# ...                ...                ...           ...
# 1124               NaN              0.524  1.557951e+11
# 1125               NaN              0.524  1.557951e+11
# 1126               NaN              0.524  1.557951e+11
# 1127               NaN              0.524  1.557951e+11
# 1128               NaN              0.524  1.557951e+11
#
#       stance_positivity_score
# 0                      35.352
# 1                      33.674
# 2                      34.606
# 3                      34.381
# 4                      34.676
# ...                       ...
# 1124                   62.262
# 1125                   62.767
# 1126                   48.192
# 1127                   70.129
# 1128                   77.272
#
# [1129 rows x 181 columns]

# %%
#save as csv (ps = positivity score)
df.to_csv("CLEAN_DATA/Data_europe_2005_2020_ps.csv")
