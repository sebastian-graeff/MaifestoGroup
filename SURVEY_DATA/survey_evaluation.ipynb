# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Clean_Manisiesta_April 25, 2024_15.40.csv')

# %%
display(df.head())
# Out:
#    Unnamed: 0  Progress  Duration (in seconds)        Recorded Date  \
# 0           0       100                    305  2024-03-25 14:59:23
# 1           1       100                    252  2024-03-25 15:00:58
# 2           2       100                    660  2024-03-25 15:05:40
# 3           3       100                    515  2024-03-25 17:19:39
# 4           4       100                    437  2024-03-25 17:22:10
#
#   Do we have your permission to record your responses to this survey?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#    What is your year of birth?  \
# 0                         1997
# 1                         1996
# 2                         1999
# 3                         1999
# 4                         1996
#
# ...

# %%
# Plot distribution of 'year of birth'
plt.figure(figsize=(10, 6))
sns.histplot(df['What is your year of birth?'], bins=30, kde=True)
plt.title('Distribution of Year of Birth')
plt.xlabel('Year of Birth')
plt.ylabel('n survey participants')
plt.show()

# Plot distribution of 'gender'
df['How do you describe yourself? - Selected Choice'] = pd.Categorical(df['How do you describe yourself? - Selected Choice'], categories=['Male', 'Female', 'Non-binary / third gender', 'Prefer not to say'], ordered=True)
plt.figure(figsize=(10, 6))
sns.histplot(df['How do you describe yourself? - Selected Choice'])
plt.title('Distribution of gender')
plt.xlabel('gender')
plt.ylabel('n survey participants')
plt.show()


# Plot distribution of 'employment status'
plt.figure(figsize=(10, 6))
sns.histplot(df['What best describes your employment status over the last three months?'])
plt.title('Distribution of Employment Status')
plt.xlabel('Employment Status')
plt.ylabel('n survey participants')
plt.show()

# Plot distribution of 'political orientation'
plt.figure(figsize=(10, 6))
sns.histplot(df['Some people talk about politics in terms of left, center and right. Where would you place yourself? - Political orientation'])
plt.title('Distribution of Political Orientation')
plt.xlabel('Political Orientation')
plt.ylabel('n survey participants')
plt.show()

# %%
# Calculate the number of unique countries in the 'country' column
unique_countries_count = df['List of Countries'].nunique()
# Calculate the count of non-null entries in the 'other_countries' column
non_null_other_countries_count = df["What other countries' culture do you identify with?"].notnull().sum()
# Calculate the percentage of 'country' values that say 'Netherlands'
netherlands_count = (df['List of Countries'] == 'Netherlands').sum()
total_countries_count = df['List of Countries'].count()
netherlands_percentage = (netherlands_count / total_countries_count) * 100


print(f"Number of unique countries in the 'country' column: {unique_countries_count}")
print(f"Number of survey participants with another country identification: {non_null_other_countries_count}")
print(f"Percentage of countries that are 'Netherlands': {netherlands_percentage:.2f}%")
# Out:
# Number of unique countries in the 'country' column: 16
# Number of survey participants with another country identification: 14
# Percentage of countries that are 'Netherlands': 50.00%
# 54

# %%
categories=['Very negative', 'Negative', 'Unsure/difficult to say', 'Positive', 'Very positive']

# Plot distribution of 'justice system manifesto'
df['What stance does this manifesto take on the justice system?'] = pd.Categorical(df['What stance does this manifesto take on the justice system?'], categories=categories, ordered=True)
plt.figure(figsize=(10, 6))
sns.histplot(df['What stance does this manifesto take on the justice system?'])
plt.title('Justice system')
plt.ylabel("participants' perception")
plt.show()

# Plot distribution of 'housing market manifesto'
df['What stance does this manifesto take on the housing market?'] = pd.Categorical(df['What stance does this manifesto take on the housing market?'], categories=categories, ordered=True)
plt.figure(figsize=(10, 6))
sns.histplot(df['What stance does this manifesto take on the housing market?'])
plt.title('housing market')
plt.ylabel("participants' perception")
plt.show()

# Plot distribution of 'government managing manifesto'
df['What stance does this manifesto take on government managing?'] = pd.Categorical(df['What stance does this manifesto take on government managing?'], categories=categories, ordered=True)
plt.figure(figsize=(10, 6))
sns.histplot(df['What stance does this manifesto take on government managing?'])
plt.title('government managing')
plt.ylabel("participants' perception")
plt.show()

# Plot distribution of 'EU manifesto'
df['What stance does this manifesto take on the European Union / community?'] = pd.Categorical(df['What stance does this manifesto take on the European Union / community?'], categories=categories, ordered=True)
plt.figure(figsize=(10, 6))
sns.histplot(df['What stance does this manifesto take on the European Union / community?'])
plt.title('EU')
plt.ylabel("participants' perception")
plt.show()

# Plot distribution of 'environmental protection manifesto'
df['What stance does this manifesto take on environmental protection?'] = pd.Categorical(df['What stance does this manifesto take on environmental protection?'], categories=categories, ordered=True)
plt.figure(figsize=(10, 6))
sns.histplot(df['What stance does this manifesto take on environmental protection?'])
plt.title('environmental protection')
plt.ylabel("participants' perception")
plt.show()

# Plot distribution of 'immigration manifesto'
df['What stance does this manifesto take on immigration?'] = pd.Categorical(df['What stance does this manifesto take on immigration?'], categories=categories, ordered=True)
plt.figure(figsize=(10, 6))
sns.histplot(df['What stance does this manifesto take on immigration?'])
plt.title('immigration')
plt.ylabel("participants' perception")
plt.show()

# Plot distribution of 'economy manifesto'
df['What stance does this manifesto take on the economy?'] = pd.Categorical(df['What stance does this manifesto take on the economy?'], categories=categories, ordered=True)
plt.figure(figsize=(10, 6))
sns.histplot(df['What stance does this manifesto take on the economy?'])
plt.title('economy')
plt.ylabel("participants' perception")
plt.show()

# %%
# Drop NaN values in the stance column
df_cleaned = df.dropna(subset=['What stance does this manifesto take on the justice system?'])
# Group by the stance column and aggregate the countries into lists
stance_countries = df_cleaned.groupby('What stance does this manifesto take on the justice system?')['List of Countries'].apply(list)
# Convert the Series to a dictionary for easier access
stance_countries_dict = stance_countries.to_dict()
# Print the resulting dictionary
print('justice system')
for stance, countries in stance_countries_dict.items():
    print(f"{stance}: {countries}")

# Drop NaN values in the stance column
df_cleaned = df.dropna(subset=['What stance does this manifesto take on the housing market?'])
# Group by the stance column and aggregate the countries into lists
stance_countries = df_cleaned.groupby('What stance does this manifesto take on the justice system?')['List of Countries'].apply(list)
# Convert the Series to a dictionary for easier access
stance_countries_dict = stance_countries.to_dict()
# Print the resulting dictionary
print('housing market')
for stance, countries in stance_countries_dict.items():
    print(f"{stance}: {countries}")

# Drop NaN values in the stance column
df_cleaned = df.dropna(subset=['What stance does this manifesto take on government managing?'])
# Group by the stance column and aggregate the countries into lists
stance_countries = df_cleaned.groupby('What stance does this manifesto take on the justice system?')['List of Countries'].apply(list)
# Convert the Series to a dictionary for easier access
stance_countries_dict = stance_countries.to_dict()
# Print the resulting dictionary
print('government managing')
for stance, countries in stance_countries_dict.items():
    print(f"{stance}: {countries}")

# Drop NaN values in the stance column
df_cleaned = df.dropna(subset=['What stance does this manifesto take on the European Union / community?'])
# Group by the stance column and aggregate the countries into lists
stance_countries = df_cleaned.groupby('What stance does this manifesto take on the justice system?')['List of Countries'].apply(list)
# Convert the Series to a dictionary for easier access
stance_countries_dict = stance_countries.to_dict()
# Print the resulting dictionary
print('EU')
for stance, countries in stance_countries_dict.items():
    print(f"{stance}: {countries}")

# Drop NaN values in the stance column
df_cleaned = df.dropna(subset=['What stance does this manifesto take on environmental protection?'])
# Group by the stance column and aggregate the countries into lists
stance_countries = df_cleaned.groupby('What stance does this manifesto take on the justice system?')['List of Countries'].apply(list)
# Convert the Series to a dictionary for easier access
stance_countries_dict = stance_countries.to_dict()
# Print the resulting dictionary
print('environment')
for stance, countries in stance_countries_dict.items():
    print(f"{stance}: {countries}")

# Drop NaN values in the stance column
df_cleaned = df.dropna(subset=['What stance does this manifesto take on immigration?'])
# Group by the stance column and aggregate the countries into lists
stance_countries = df_cleaned.groupby('What stance does this manifesto take on the justice system?')['List of Countries'].apply(list)
# Convert the Series to a dictionary for easier access
stance_countries_dict = stance_countries.to_dict()
# Print the resulting dictionary
print('immigration')
for stance, countries in stance_countries_dict.items():
    print(f"{stance}: {countries}")

# Drop NaN values in the stance column
df_cleaned = df.dropna(subset=['What stance does this manifesto take on the economy?'])
# Group by the stance column and aggregate the countries into lists
stance_countries = df_cleaned.groupby('What stance does this manifesto take on the justice system?')['List of Countries'].apply(list)
# Convert the Series to a dictionary for easier access
stance_countries_dict = stance_countries.to_dict()
# Print the resulting dictionary
print('economy')
for stance, countries in stance_countries_dict.items():
    print(f"{stance}: {countries}")
# Out:
# justice system
# Negative: ['Netherlands', 'Netherlands']
# Positive: ['Netherlands', 'Cyprus', 'Russian Federation', 'South Korea', 'Netherlands', 'Netherlands', 'Netherlands', 'Netherlands', 'Netherlands']
# Unsure/difficult to say: ['Netherlands', 'Germany', 'Germany', 'Finland']
# Very positive: ['Netherlands', 'Lithuania']
# housing market
# Positive: ['South Korea', 'Netherlands', 'Netherlands', 'Netherlands']
# Unsure/difficult to say: ['Netherlands']
# Very positive: ['Netherlands']
# government managing
# Positive: ['Netherlands', 'Cyprus', 'South Korea']
# Unsure/difficult to say: ['Netherlands']
# EU
# Negative: ['Netherlands', 'Netherlands']
# Positive: ['Netherlands', 'Netherlands']
# Very positive: ['Netherlands', 'Lithuania']
# environment
# Positive: ['Netherlands', 'Cyprus', 'Russian Federation', 'Netherlands', 'Netherlands']
# Unsure/difficult to say: ['Germany', 'Finland']
# immigration
# Positive: ['Russian Federation', 'Netherlands']
# ...
